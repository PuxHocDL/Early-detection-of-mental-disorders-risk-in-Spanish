# %% [markdown]
# # Access the MentalRiskEs data and interact with the server
#
# This notebook has been developed by the [SINAI](https://sinai.ujaen.es/) research group for its usage in the [MentalRiskES](https://sites.google.com/view/mentalriskes2025/) evaluation campaign at IberLEF 2025.
#
# **NOTE 1**: Please visit the [MentalRiskES competition website](https://sites.google.com/view/mentalriskes2025/evaluation) to read the instructions about how to download the data and interact with the server to send the predictions of your system.
#
# **NOTE 2**: Along the code, please replace "URL" by the URL server and "TOKEN" by your personal token.
#
# Remember this is a support to help you to develop your own system of communication with our server. We recommend you to download it as a Python script instead of working directly on colab and adapt the code to your needs.

# %% [markdown]
# # Install CodeCarbon package
# Read the [documentation](https://mlco2.github.io/codecarbon/) about the library if necessary. Remember that we provide a [CodeCarbon notebook](https://colab.research.google.com/drive/1boavnGOir0urui8qktbZaOmOV2pS5cn6?usp=sharing) with the example in its specific use in our competition.

# %%
import os
import json
import random
from collections import defaultdict

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence

from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import f1_score

from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification


from datasets import Dataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Import libraries

# %%
import requests, zipfile, io
from requests.adapters import HTTPAdapter, Retry
from typing import List, Dict
import random
import json
import os
import pandas as pd
from codecarbon import EmissionsTracker

# %% [markdown]
# # Endpoints
# These URL addresses are necessary for the connection to the server.
#
# **IMPORTANT:** Replace "URL" by the URL server and "TOKEN" by your user token.

# %%
URL = "" #my URL
TOKEN = "" #my token 

# Download endpoints     Dùng để tải dữ liệu về máy
ENDPOINT_DOWNLOAD_TRIAL = URL+"/{TASK}/download_trial/{TOKEN}"
ENDPOINT_DOWNLOAD_TRAIN = URL+"/{TASK}/download_train/{TOKEN}"

# Trial endpoints        Dùng để gửi kết quả dự đoán lên server (lúc trial)
ENDPOINT_GET_MESSAGES_TRIAL = URL+"/{TASK}/getmessages_trial/{TOKEN}"
ENDPOINT_SUBMIT_DECISIONS_TRIAL = URL+"/{TASK}/submit_trial/{TOKEN}/{RUN}"

# Test endpoints         
# Dùng để gửi kết quả dự đoán lên server (lúc thât, cẩn thận vì khi nộp là không nộp lại được)
ENDPOINT_GET_MESSAGES = URL+"/{TASK}/getmessages/{TOKEN}"
ENDPOINT_SUBMIT_DECISIONS = URL+"/{TASK}/submit/{TOKEN}/{RUN}"

# %% [markdown]
# # Download Data
# To download the data, you can make use of the **function defined in the following**.
#
# The following function download the trial data. To adapt it to download the train and test data, follow the instructions given in the [website of the competition](https://sites.google.com/view/mentalriskes2024/evaluation).

# %%
def download_messages_trial(task: str, token: str):
    """ Allows you to download the trial data of the task.
        Args:
          task (str): task from which the data is to be retrieved
          token (str): authentication token
    """

    response = requests.get(ENDPOINT_DOWNLOAD_TRIAL.format(TASK=task, TOKEN=token)) # gửi request đến server để lấy data (trial)

    if response.status_code != 200:
        print("Trial - Status Code " + task + ": " + str(response.status_code) + " - Error: " + str(response.text))
    else:
      z = zipfile.ZipFile(io.BytesIO(response.content))
      os.makedirs("./data/{task}/trial/".format(task=task))
      z.extractall("./data/{task}/trial/".format(task=task))

# %%
def download_messages_train(task: str, token: str):
    """ Allows you to download the train data of the task.
        Args:
          task (str): task from which the data is to be retrieved
          token (str): authentication token
    """
    response = requests.get(ENDPOINT_DOWNLOAD_TRAIN.format(TASK=task, TOKEN=token))

    if response.status_code != 200:
        print("Train - Status Code " + task + ": " + str(response.status_code) + " - Error: " + str(response.text))
    else:
      z = zipfile.ZipFile(io.BytesIO(response.content))
      os.makedirs("./data/{task}/train/".format(task=task),exist_ok=True)
      z.extractall("./data/{task}/train/".format(task=task))

# %%
def map_emoji_to_spanish(emoji=None):
    emoji_map = {
        "🔝": "arriba",
        "👎": "no me gusta",
        "😳": "sorprendido",
        "4️⃣": "cuatro",
        "🖐🏼": "mano abierta",
        "💎": "diamante",
        "🤣": "riendo fuerte",
        "🤞🏻": "dedos cruzados",
        "🍺": "cerveza",
        "❣": "corazón exclamación",
        "🤡": "payaso",
        "🎅🏻": "Papá Noel",
        "⬆": "subir",
        "💸": "dinero volando",
        "🤤": "babeando",
        "❌": "cruz",
        "🙌🏻": "manos arriba",
        "🤩": "asombrado",
        "🇵🇪": "Perú",
        "🤠": "vaquero",
        "🟣": "círculo morado",
        "🖐🏽": "mano abierta",
        "🙃": "cara invertida",
        "🐸": "rana",
        "👆🏼": "señalando arriba",
        "🈚": "gratis",
        "🌐": "mundo",
        "🎁": "regalo",
        "🎉": "celebración",
        "😵‍💫": "mareado",
        "🌝": "luna llena",
        "🙋‍♂": "hombre levantando mano",
        "3️⃣": "tres",
        "🔮": "bola de cristal",
        "😰": "nervioso",
        "😨": "miedo",
        "❓": "pregunta",
        "☝🏻": "dedo arriba",
        "🥲": "lágrimas de alegría",
        "✊🏼": "puño levantado",
        "✊": "puño",
        "🧘🏻‍♂": "meditación",
        "🧐": "curioso",
        "👏🏾": "aplausos",
        "🐳": "ballena",
        "💪🏼": "fuerza",
        "✅": "aprobado",
        "🤦🏼‍♂": "vergüenza",
        "😍": "enamorado",
        "👻": "fantasma",
        "😂": "riendo",
        "💪🏻": "fuerte",
        "🫤": "decepción",
        "⚽": "fútbol",
        "🥚": "huevo",
        "🙏": "rezando",
        "🤙": "llámame",
        "🙄": "aburrido",
        "😲": "asombro",
        "♥": "corazón",
        "🍎": "manzana",
        "🐻": "oso",
        "🤪": "loco",
        "👆🏽": "señalando arriba",
        "🎢": "montaña rusa",
        "🙌": "celebrando",
        "🌘": "luna menguante",
        "🫡": "saludo",
        "🙋🏻‍♀": "mujer levantando mano",
        "🤦‍♂": "error",
        "🌊": "ola",
        "😉": "guiño",
        "🥶": "frío",
        "💋": "beso",
        "🇺🇦": "Ucrania",
        "😶‍🌫": "confundido",
        "🌬": "viento",
        "💩": "mierda",
        "👌🏼": "perfecto",
        "🙆‍♂": "hombre OK",
        "💪🏽": "fuerza",
        "😱": "gritando",
        "1️⃣": "uno",
        "🤘": "rock",
        "👉": "señalando derecha",
        "🙂": "sonriendo",
        "👁": "ojo",
        "👀": "ojos",
        "🔥": "fuego",
        "⏺": "grabar",
        "😅": "sudando",
        "❗": "exclamación",
        "😕": "confuso",
        "🥒": "pepino",
        "🎂": "torta",
        "😥": "aliviado",
        "✌🏽": "victoria",
        "🎾": "tenis",
        "💚": "corazón verde",
        "💔": "corazón roto",
        "👍": "bien",
        "🐶": "perro",
        "✔": "verificado",
        "✌🏻": "paz",
        "💪": "músculo",
        "🎈": "globo",
        "🤑": "dinero en la cara",
        "😾": "gato enfadado",
        "💵": "billete",
        "👋🏻": "saludando",
        "👈🏻": "señalando izquierda",
        "💰": "bolsa de dinero",
        "🎼": "música",
        "🐮": "vaca",
        "🇦🇷": "Argentina",
        "🤷🏼‍♀": "mujer encogiéndose",
        "💃": "bailando",
        "🤮": "vomitando",
        "🇷🇺": "Rusia",
        "😎": "genial",
        "🥳": "fiesta",
        "⚰": "ataúd",
        "💯": "cien puntos",
        "📈": "gráfico subiendo",
        "😭": "llorando",
        "😪": "somnoliento",
        "🤞🏼": "suerte",
        "🤦🏽‍♂": "hombre avergonzado",
        "▶": "reproducir",
        "⛔": "prohibido",
        "🎶": "notas musicales",
        "🙊": "mono callado",
        "🌚": "luna nueva",
        "👏": "aplaudiendo",
        "🙏🏽": "rezando",
        "😄": "feliz",
        "🤦🏻‍♂": "error hombre",
        "🇨🇳": "China",
        "👌🏻": "OK",
        "🤙🏻": "llámame",
        "🇳🇬": "Nigeria",
        "😃": "alegre",
        "ℹ️": "información",
        "🗣": "hablando",
        "🙌🏼": "manos levantadas",
        "🤞": "cruzando dedos",
        "😜": "broma",
        "🎵": "nota musical",
        "🤟": "te amo",
        "✈": "avión",
        "👌🏽": "perfecto",
        "🤦🏽": "vergüenza",
        "👍🏾": "bien",
        "🔹": "diamante azul",
        "😝": "lengua fuera",
        "💶": "euro",
        "🤓": "nerd",
        "😶": "sin expresión",
        "🐁": "ratón",
        "🐗": "jabalí",
        "🤦🏻‍♀": "mujer avergonzada",
        "🍏": "manzana verde",
        "🟢": "círculo verde",
        "🙌🏽": "celebración",
        "🇪🇸": "España",
        "✨": "brillo",
        "🤷🏻‍♂": "hombre encogiéndose",
        "🚨": "alarma",
        "🥰": "amor",
        "☺": "sonrisa",
        "🤷‍♂": "duda",
        "🤯": "cabeza explotando",
        "🥺": "suplicando",
        "🐟": "pez",
        "🇮🇳": "India",
        "😐": "neutral",
        "😁": "sonriendo amplio",
        "🙋🏻‍♂": "levantando mano",
        "😓": "sudor",
        "🕺": "bailando",
        "😯": "sorprendido",
        "👉🏻": "señalando derecha",
        "💥": "explosión",
        "😢": "llorando",
        "🦖": "T-Rex",
        "⚡": "rayo",
        "😴": "durmiendo",
        "🫣": "espiando",
        "😻": "gato enamorado",
        "🥵": "caliente",
        "👍🏻": "pulgar arriba",
        "🇧🇾": "Bielorrusia",
        "🤷🏽‍♀": "mujer dudando",
        "😋": "saboreando",
        "🚫": "prohibido",
        "👅": "lengua",
        "😆": "riendo mucho",
        "😊": "sonriendo feliz",
        "😇": "ángel",
        "😠": "enojado",
        "🌎": "Américas",
        "⬇": "bajar",
        "😞": "triste",
        "🔵": "círculo azul",
        "📨": "correo",
        "👆": "arriba",
        "😘": "besando",
        "🌖": "luna gibosa",
        "❤": "corazón rojo",
        "☝": "dedo arriba",
        "✌": "victoria",
        "🍻": "brindis",
        "🤝": "apretón de manos",
        "👋": "saludo",
        "💲": "dólar",
        "👍🏼": "bien",
        "🚶🏻‍♂": "hombre caminando",
        "🤔": "pensando",
        "😹": "gato riendo",
        "🫵": "señalando",
        "🤭": "riendo callado",
        "🪂": "paracaídas",
        "😈": "diablo",
        "🔰": "principiante",
        "🫀": "corazón",
        "😒": "molesto",
        "🤷": "no sé",
        "😀": "felicidad",
        "🍀": "trébol",
        "🔪": "cuchillo",
        "😮": "boca abierta",
        "💬": "hablar",
        "✋": "mano levantada",
        "😌": "alivio",
        "💦": "sudor",
        "🤷🏼‍♂": "duda",
        "☹": "tristeza",
        "🤨": "sospecha",
        "🤙🏽": "llámame",
        "🔻": "triángulo abajo",
        "🛍": "compras",
        "🤧": "estornudo",
        "💫": "mareo",
        "👼": "ángel",
        "🤌": "pellizco",
        "💨": "rápido",
        "😛": "lengua fuera",
        "🎄": "árbol de Navidad",
        "🥹": "lágrimas contenidas",
        "☀": "sol",
        "🌕": "luna llena",
        "🇺🇸": "Estados Unidos",
        "👏🏼": "aplausos",
        "‼": "doble exclamación",
        "🚀": "cohete",
        "😡": "furioso",
        "😬": "nervios",
        "🔴": "círculo rojo",
        "🙏🏻": "orando",
        "🙈": "mono tapándose",
        "🦥": "perezoso",
        "🌙": "luna creciente",
        "👈": "señalando izquierda",
        "🐷": "cerdo",
        "🥸": "disfrazado",
        "😏": "sonrisa pícara",
        "😚": "beso cerrado",
        "⚓": "ancla",
        "👌": "OK",
        "🤟🏻": "te amo",
        "🌌": "vía láctea",
        "⚠": "advertencia",
        "🥱": "bostezando",
        "🐬": "delfín",
        "📊": "gráfico",
        "🐀": "rata",
        "🤗": "abrazo",
        "😔": "pensativo",
        "👏🏻": "aplaudiendo",
        "🇧🇬": "Bulgaria",
        "🥴": "mareado"
    }
    if emoji is None:
        return emoji_map  
    return emoji_map.get(emoji, emoji) 

def replace_emojis_in_text(text):
    result = text
    emoji_dict = map_emoji_to_spanish()
    for emoji, spanish_text in emoji_dict.items():
        result = result.replace(emoji, f" {spanish_text} ")
    words = result.split()
    if not words:
        return ""
    cleaned_words = [words[0]]
    for i in range(1, len(words)):
        if words[i] != words[i - 1]:
            cleaned_words.append(words[i])
    return " ".join(cleaned_words).strip()

def process_data(text):
    return replace_emojis_in_text(text)

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, input_size, h_size, output_dim, dropout=0):
        super().__init__()
        self.input_size = input_size
        self.h_size = h_size
        self.output_dim = output_dim
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=h_size, num_layers=1, 
                           batch_first=False, dropout=dropout, bidirectional=True)
        self.attention = nn.Linear(2 * h_size, 1)
        self.classifier = nn.Linear(2 * h_size, output_dim)

    def forward(self, seq_data, seq_lens, state=None):
        lstm_out, _ = self.lstm(seq_data)
        attention_weights = torch.softmax(self.attention(lstm_out), dim=0)
        context_vector = torch.sum(attention_weights * lstm_out, dim=0)
        output = self.classifier(context_vector)
        return output

    def predict_all_timesteps(self, seq_data, seq_lens, state=None):
        # seq_data: [seq_len, batch_size, input_size]
        batch_size = seq_data.size(1)
        if state is None:
            lstm_out, (h_n, c_n) = self.lstm(seq_data)
        else:
            h_n, c_n = state
            lstm_out, (h_n, c_n) = self.lstm(seq_data, (h_n, c_n))
        logits_all = self.classifier(lstm_out)  # [seq_len, batch_size, output_dim]
        pred_all = torch.argmax(logits_all, dim=2)  # [seq_len, batch_size]
        ts_predictions = []
        for i in range(batch_size):
            ts_predictions.append(pred_all[:seq_lens[0, i].item(), i].cpu().numpy())
        return ts_predictions, (h_n, c_n)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
name = 'pysentimiento/robertuito-sentiment-analysis'
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModel.from_pretrained(name)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at pysentimiento/robertuito-sentiment-analysis and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Hàm lấy embedding
def get_cls_embeddings(messages, model, tokenizer, device, m_length=96):
    model.to(device)
    model.eval()
    with torch.no_grad():
        inputs = tokenizer(messages, padding=True, truncation=True, max_length=m_length, return_tensors='pt')
        inputs = {k: v.to(device) for k, v in inputs.items()}
        output = model(**inputs)
        embeddings = output.last_hidden_state[:, 0, :]
    return embeddings

# %%
def process_round_task1(data, embedding_func, rnn, device, state=None):
    messages_by_subject = defaultdict(list)
    for x in data:
        messages_by_subject[x['nick']].append(process_data(x['message']))
    
    subjects = list(messages_by_subject.keys())
    batch_size = len(subjects)
    
    if state is None:
        h_n = torch.zeros(2, batch_size, rnn.h_size, dtype=torch.float32)
        c_n = torch.zeros(2, batch_size, rnn.h_size, dtype=torch.float32)
        state = (h_n, c_n)
    else:
        h_n, c_n = state
        current_batch_size = h_n.size(1)
        if current_batch_size != batch_size:
            if current_batch_size < batch_size:
                h_n = torch.cat([h_n, torch.zeros(2, batch_size - current_batch_size, rnn.h_size)], dim=1)
                c_n = torch.cat([c_n, torch.zeros(2, batch_size - current_batch_size, rnn.h_size)], dim=1)
            else:
                h_n = h_n[:, :batch_size, :]
                c_n = c_n[:, :batch_size, :]
    
    predictions = {}
    h_new, c_new = [], []
    for i, subject in enumerate(subjects):
        messages = messages_by_subject[subject]
        embeddings = embedding_func(messages, model, tokenizer, device).unsqueeze(1)  # [T, 1, 768]
        seq_lens = torch.tensor([[len(messages)]], dtype=torch.long).to(device)
        h_states = h_n[:, i:i+1, :].to(device)
        c_states = c_n[:, i:i+1, :].to(device)
        pred, (h, c) = rnn.predict_all_timesteps(embeddings, seq_lens, (h_states, c_states))
        pred_seq = np.atleast_1d(pred[0])
        if len(messages) == 1:
            # Nếu chỉ có một tin nhắn, trả về dự đoán trực tiếp
            predictions[subject] = int(pred_seq[0])
        else:
            # Nếu có nhiều tin nhắn, chọn nhãn đầu tiên khác 0
            idxs = np.nonzero(pred_seq)[0]
            predictions[subject] = int(pred_seq[idxs[0]]) if len(idxs) > 0 else 0
        h_new.append(h.cpu())
        c_new.append(c.cpu())
    
    h_new = torch.cat(h_new, dim=1)
    c_new = torch.cat(c_new, dim=1)
    return predictions, (h_new, c_new)

# %%
TYPE_MAP = {0: 'betting', 1: 'onlinegaming', 2: 'trading', 3: 'lootboxes'}
def process_round_task2(data, embedding_func, rnn, bert_model, bert_tokenizer, device, state=None):
    from collections import defaultdict
    import torch
    import numpy as np
    
    messages_by_subject = defaultdict(list)
    for x in data:
        messages_by_subject[x['nick']].append(process_data(x['message']))
    
    subjects = list(messages_by_subject.keys())
    batch_size = len(subjects)
    
    if state is None:
        h_n = torch.zeros(2, batch_size, rnn.h_size, dtype=torch.float32)
        c_n = torch.zeros(2, batch_size, rnn.h_size, dtype=torch.float32)
        state = (h_n, c_n)
    else:
        h_n, c_n = state
        current_batch_size = h_n.size(1)
        if current_batch_size != batch_size:
            if current_batch_size < batch_size:
                h_n = torch.cat([h_n, torch.zeros(2, batch_size - current_batch_size, rnn.h_size)], dim=1)
                c_n = torch.cat([c_n, torch.zeros(2, batch_size - current_batch_size, rnn.h_size)], dim=1)
            else:
                h_n = h_n[:, :batch_size, :]
                c_n = c_n[:, :batch_size, :]
    
    predictions = {}
    type_predictions = {}
    h_new, c_new = [], []
    for i, subject in enumerate(subjects):
        messages = messages_by_subject[subject]
        # Dự đoán rủi ro (predictions) bằng LSTMClassifier
        embeddings = embedding_func(messages, model, tokenizer, device).unsqueeze(1)  # [T, 1, 768]
        seq_lens = torch.tensor([[len(messages)]], dtype=torch.long).to(device)
        h_states = h_n[:, i:i+1, :].to(device)
        c_states = c_n[:, i:i+1, :].to(device)
        pred, (h, c) = rnn.predict_all_timesteps(embeddings, seq_lens, (h_states, c_states))
        pred_seq = np.atleast_1d(pred[0])
        idxs = np.nonzero(pred_seq)[0]
        predictions[subject] = int(pred_seq[idxs[0]]) if len(idxs) > 0 else 0
        h_new.append(h.cpu())
        c_new.append(c.cpu())
        
        # Dự đoán loại nghiện (types) bằng BERT, gộp tất cả tin nhắn
        bert_model.to(device)
        bert_model.eval()
        with torch.no_grad():
            combined_text = ' '.join(messages)
            inputs = bert_tokenizer(
                combined_text, padding=True, truncation=True, max_length=256, return_tensors='pt'
            )
            inputs = {k: v.to(device) for k, v in inputs.items()}
            outputs = bert_model(**inputs)
            logits = outputs.logits
            pred = torch.argmax(logits, dim=-1).cpu().numpy()[0]
            type_predictions[subject] = TYPE_MAP[pred]
    
    h_new = torch.cat(h_new, dim=1)
    c_new = torch.cat(c_new, dim=1)
    response = {
        'predictions': predictions,
        'types': type_predictions
    }
    return response, (h_new, c_new)

# %% [markdown]
# # Client Server
# This class simulates communication with our server. The following code established the conection with the server client and simulate the GET and POST requests.
#
# **IMPORTANT NOTE:** Please pay attention to the basic functions and remember that it is only a base for your system.

# %%
from datetime import datetime, timedelta

# %%
class Client_task1_2:
    def __init__(self, task: str, token: str, rnn_models, embedding_func, bert_model, bert_tokenizer, submit_to_server: bool = False):
        self.task = task
        self.token = token
        self.rnn_models = rnn_models
        self.embedding_func = embedding_func
        self.bert_model = bert_model
        self.bert_tokenizer = bert_tokenizer
        self.submit_to_server = submit_to_server
        self.relevant_cols = [
            'duration', 'emissions', 'cpu_energy', 'gpu_energy', 'ram_energy',
            'energy_consumed', 'cpu_count', 'gpu_count', 'cpu_model', 'gpu_model',
            'ram_total_size', 'country_iso_code'
        ]
        self.url_base = "http://s3-ceatic.ujaen.es:8036"
        self.ENDPOINT_GET_MESSAGES = f"{self.url_base}/{{TASK}}/getmessages/{{TOKEN}}"
        self.ENDPOINT_SUBMIT_DECISIONS = f"{self.url_base}/{{TASK}}/submit/{{TOKEN}}/{{RUN}}"
        self.all_messages_task1 = []
        self.all_messages_task2 = []
        self.states_task1 = [None, None, None]
        self.states_task2 = [None, None, None]
        self.current_messages_task1 = []
        self.current_messages_task2 = []

    def get_messages_task1(self, retries: int, backoff: float) -> list:
        """GET messages for Task 1 for the current run."""
        session = requests.Session()
        retries = Retry(total=retries, backoff_factor=backoff, status_forcelist=[500, 502, 503, 504])
        session.mount('http://', HTTPAdapter(max_retries=retries))
        response = session.get(self.ENDPOINT_GET_MESSAGES.format(TASK="task1", TOKEN=self.token))
        
        if response.status_code != 200:
            print(f"GET - Task 1 - Status Code {response.status_code} - Error: {response.text}")
            self.current_messages_task1 = []
        else:
            self.current_messages_task1 = json.loads(response.content)
            self.all_messages_task1.extend(self.current_messages_task1)
            os.makedirs('./data/run0/task1', exist_ok=True)
            with open(f'./data/run0/task1/messages.json', 'w+', encoding='utf8') as json_file:
                json.dump(self.current_messages_task1, json_file, ensure_ascii=False)
            print(f"Task 1: Retrieved {len(self.current_messages_task1)} messages")
        
        return self.current_messages_task1

    def get_messages_task2(self, retries: int, backoff: float) -> list:
        """GET messages for Task 2 for the current run."""
        session = requests.Session()
        retries = Retry(total=retries, backoff_factor=backoff, status_forcelist=[500, 502, 503, 504])
        session.mount('http://', HTTPAdapter(max_retries=retries))
        response = session.get(self.ENDPOINT_GET_MESSAGES.format(TASK="task2", TOKEN=self.token))
        
        if response.status_code != 200:
            print(f"GET - Task 2 - Status Code {response.status_code} - Error: {response.text}")
            self.current_messages_task2 = []
        else:
            self.current_messages_task2 = json.loads(response.content)
            self.all_messages_task2.extend(self.current_messages_task2)
            os.makedirs('./data/run0/task2', exist_ok=True)
            with open(f'./data/run0/task2/messages.json', 'w+', encoding='utf8') as json_file:
                json.dump(self.current_messages_task2, json_file, ensure_ascii=False)
            print(f"Task 2: Retrieved {len(self.current_messages_task2)} messages")
        
        return self.current_messages_task2

    def predict_and_submit_task1(self, run: int, retries: int, backoff: float, device):
        if run not in [0, 1, 2]:
            print(f"Invalid run number: {run}. Must be 0, 1, or 2.")
            return
        if not self.current_messages_task1:
            print(f"Run {run}: No messages to process for Task 1")
            return
        print(f"------------------- Processing Task 1, Run {run}")
        
        with EmissionsTracker(
            save_to_file=True, log_level="WARNING", tracking_mode="process",
            output_dir=".", output_file=f"emissions_task1_run{run}.csv"
        ) as tracker:
            predictions_task1, self.states_task1[run] = process_round_task1(
                data=self.all_messages_task1, embedding_func=self.embedding_func, 
                rnn=self.rnn_models[run], device=device, state=self.states_task1[run]
            )

        try:
            emissions_file = f"emissions.csv"
            if os.path.exists(emissions_file) and os.path.getsize(emissions_file) > 0:
                df = pd.read_csv(emissions_file)
                if not df.empty:
                    measurements_task1 = df.iloc[-1][self.relevant_cols].to_dict()
                else:
                    print(f"Run {run}: Warning: {emissions_file} is empty, using default emissions")
                    measurements_task1 = {col: 0.0 for col in self.relevant_cols}
            else:
                print(f"Run {run}: Warning: {emissions_file} not found or empty, using default emissions")
                measurements_task1 = {col: 0.0 for col in self.relevant_cols}
        except Exception as e:
            print(f"Run {run}: Error reading {emissions_file}: {e}, using default emissions")
            measurements_task1 = {col: 0.0 for col in self.relevant_cols}

        data_run = {
            "predictions": predictions_task1,
            "emissions": measurements_task1
        }
        print(f"\nData to be sent for Task 1 - Run {run}:")
        data = [json.dumps(data_run)]
        print(data)

        if self.submit_to_server:
            session = requests.Session()
            retries = Retry(total=retries, backoff_factor=backoff, status_forcelist=[500, 502, 503, 504])
            session.mount('http://', HTTPAdapter(max_retries=retries))
            endpoint = self.ENDPOINT_SUBMIT_DECISIONS.format(TASK="task1", TOKEN=self.token, RUN=run)
            print(f"URL to be sent: {endpoint}")
            try:
                response = session.post(endpoint, json=[data[0]])
                print(f"POST - Task 1 - Run {run} - Status Code {response.status_code} - Message: {response.text}")
            except Exception as e:
                print(f"POST - Task 1 - Run {run} - Error: {str(e)}")
        else:
            print(f"Submit to server is disabled. Data saved locally.")

        os.makedirs('./data/preds/task1', exist_ok=True)
        file_path = f'./data/preds/task1/run{run}.json'
        existing_data = []
        if os.path.exists(file_path):
            with open(file_path, 'r', encoding='utf8') as f:
                existing_data = json.load(f)
        existing_data.append(data[0])
        with open(file_path, 'w+', encoding='utf8') as f:
            json.dump(existing_data, f, ensure_ascii=False, indent=2)
        print(f"Saved Task 1 - Run {run} to {file_path}")

    def predict_and_submit_task2(self, run: int, retries: int, backoff: float, device):
        if run not in [0, 1, 2]:
            print(f"Invalid run number: {run}. Must be 0, 1, or 2.")
            return
        if not self.current_messages_task2:
            print(f"Run {run}: No messages to process for Task 2")
            return
        print(f"------------------- Processing Task 2, Run {run}")
        
        with EmissionsTracker(
            save_to_file=True, log_level="WARNING", tracking_mode="process",
            output_dir=".", output_file=f"emissions_task2_run{run}.csv"
        ) as tracker:
            predictions_task2, self.states_task2[run] = process_round_task2(
                data=self.all_messages_task2, embedding_func=self.embedding_func, 
                rnn=self.rnn_models[run], bert_model=self.bert_model, 
                bert_tokenizer=self.bert_tokenizer, device=device, state=self.states_task2[run]
            )

        try:
            emissions_file = f"emissions.csv"
            if os.path.exists(emissions_file) and os.path.getsize(emissions_file) > 0:
                df = pd.read_csv(emissions_file)
                if not df.empty:
                    measurements_task2 = df.iloc[-1][self.relevant_cols].to_dict()
                else:
                    print(f"Run {run}: Warning: {emissions_file} is empty, using default emissions")
                    measurements_task2 = {col: 0.0 for col in self.relevant_cols}
            else:
                print(f"Run {run}: Warning: {emissions_file} not found or empty, using default emissions")
                measurements_task2 = {col: 0.0 for col in self.relevant_cols}
        except Exception as e:
            print(f"Run {run}: Error reading {emissions_file}: {e}, using default emissions")
            measurements_task2 = {col: 0.0 for col in self.relevant_cols}


        data_run = {
            "predictions": predictions_task2['predictions'],
            "types": predictions_task2['types'],
            "emissions": measurements_task2
        }
        print(f"\nData to be sent for Task 2 - Run {run}:")
        data = [json.dumps(data_run)]
        print(data)

        if self.submit_to_server:
            session = requests.Session()
            retries = Retry(total=retries, backoff_factor=backoff, status_forcelist=[500, 502, 503, 504])
            session.mount('http://', HTTPAdapter(max_retries=retries))
            endpoint = self.ENDPOINT_SUBMIT_DECISIONS.format(TASK="task2", TOKEN=self.token, RUN=run)
            print(f"URL to be sent: {endpoint}")
            try:
                response = session.post(endpoint, json=[data[0]])
                print(f"POST - Task 2 - Run {run} - Status Code {response.status_code} - Message: {response.text}")
            except Exception as e:
                print(f"POST - Task 2 - Run {run} - Error: {str(e)}")
        else:
            print(f"Submit to server is disabled. Data saved locally.")

        os.makedirs('./data/preds/task2', exist_ok=True)
        file_path = f'./data/preds/task2/run{run}.json'
        existing_data = []
        if os.path.exists(file_path):
            with open(file_path, 'r', encoding='utf8') as f:
                existing_data = json.load(f)
        existing_data.append(data[0])
        with open(file_path, 'w+', encoding='utf8') as f:
            json.dump(existing_data, f, ensure_ascii=False, indent=2)
        print(f"Saved Task 2 - Run {run} to {file_path}")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
name = 'pysentimiento/robertuito-sentiment-analysis'
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModel.from_pretrained(name)

# Tải mô hình BERT cho Task 2
bert_checkpoint = './model_1'  
bert_tokenizer = AutoTokenizer.from_pretrained("PlanTL-GOB-ES/roberta-base-bne")
bert_model = AutoModelForSequenceClassification.from_pretrained(bert_checkpoint, num_labels=4)
bert_model.eval()

# Khởi tạo RNN models
task_rnn_1 = LSTMClassifier(768, 64, 2)
task_rnn_1.load_state_dict(torch.load('pre_trained_models_task1/processed_data_h_64_bs_2_0.95_0.05/net_params.pt'))
task_rnn_1.eval()
task_rnn_1.to(device)

task_rnn_2 = LSTMClassifier(768, 32, 2)
task_rnn_2.load_state_dict(torch.load('pre_trained_models_old/processed_data_h_32_bs_2_0.95_0.05/net_params.pt'))
task_rnn_2.eval()
task_rnn_2.to(device)

task_rnn_3 = LSTMClassifier(768, 32, 2)
task_rnn_3.load_state_dict(torch.load('pre_trained_models_task1/processed_data_h_32_bs_2_0.95_0.05/net_params.pt'))
task_rnn_3.eval()
task_rnn_3.to(device)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at pysentimiento/robertuito-sentiment-analysis and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LSTMClassifier(
#   (lstm): LSTM(768, 32, bidirectional=True)
#   (attention): Linear(in_features=64, out_features=1, bias=True)
#   (classifier): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
client = Client_task1_2(rnn_models=[task_rnn_1, task_rnn_2, task_rnn_3], embedding_func=get_cls_embeddings, bert_model=bert_model, bert_tokenizer=bert_tokenizer, token='your_token_here', submit_to_server=True)

# %%
rnn_models = [task_rnn_1, task_rnn_2, task_rnn_3]
client.get_messages_task2(retries=5, backoff=0.1)
client.predict_and_submit_task2(
    run=0, retries=5, backoff=0.1, device=device)
# Out:
# [codecarbon ERROR @ 16:44:26] Error: Another instance of codecarbon is probably running as we find `C:\Users\PHUCNG~1\AppData\Local\Temp\.codecarbon.lock`. Turn off the other instance to be able to run this one or use `allow_multiple_runs` or delete the file. Exiting.
# [codecarbon WARNING @ 16:44:26] Another instance of codecarbon is already running. Exiting.
# Task 2: Retrieved 160 messages
# ------------------- Processing Task 2, Run 0
# [codecarbon WARNING @ 16:44:29] Another instance of codecarbon is already running. Exiting.
# Run 0: Warning: emissions_task2_run0.csv not found or empty, using default emissions
#
# Data to be sent for Task 2 - Run 0:
# ['{"predictions": {"user4550": 0, "user4554": 0, "user4808": 0, "user482": 0, "user485": 0, "user5158": 0, "user531": 0, "user546": 0, "user557": 0, "user6190": 0, "user6463": 1, "user6995": 0, "user7135": 0, "user7194": 0, "user997": 0, "user4174": 0, "user4203": 0, "user4218": 0, "user4222": 0, "user4333": 0, "user4545": 0, "user4581": 0, "user4840": 0, "user5188": 0, "user5354": 0, "user5913": 0, "user5975": 0, "user6062": 0, "user6128": 0, "user6576": 0, "user6927": 0, "user6937": 0, "user7061": 0, "user7144": 0, "user7244": 0, "user18721": 0, "user18730": 1, "user18759": 0, "user18891": 0, "user18944": 0, "user19224": 0, "user19263": 0, "user19444": 0, "user20483": 0, "user20639": 0, "user21289": 0, "user21294": 0, "user21422": 0, "user22380": 0, "user23816": 0, "user24387": 0, "user24513": 0, "user27647": 0, "user27670": 0, "user28298": 0, "user19643": 0, "user19737": 0, "user19767": 0, "user19891": 0, "user19956": 0, "user19982": 0, "user20079": 0, "user20546": 0, "user20785": 0, "user21081": 0, "user21103": 1, "user21282": 0, "user21406": 0, "user21595": 0, "user22309": 0, "user22341": 0, "user22443": 0, "user24038": 0, "user26003": 0, "user26424": 0, "user26426": 0, "user28183": 0, "user28187": 0, "user28306": 0, "user7555": 0, "user7579": 0, "user7580": 0, "user7591": 0, "user7592": 0, "user7613": 0, "user7621": 0, "user7652": 0, "user7660": 0, "user7679": 0, "user7698": 0, "user7816": 0, "user7836": 0, "user7876": 0, "user7884": 0, "user7899": 0, "user7920": 0, "user8023": 0, "user8137": 0, "user8303": 0, "user8404": 0, "user8497": 0, "user8696": 0, "user8775": 0, "user8834": 0, "user8875": 0, "user8924": 0, "user8945": 0, "user8971": 0, "user9116": 0, "user9131": 0, "user9268": 0, "user9358": 0, "user9366": 0, "user9457": 0, "user13834": 0, "user14047": 0, "user14065": 0, "user14232": 0, "user14366": 0, "user14382": 0, "user14527": 0, "user14529": 0, "user14758": 0, "user14793": 0, "user14816": 0, "user14920": 0, "user15125": 0, "user15166": 0, "user15212": 0, "user15400": 0, "user15503": 0, "user15528": 0, "user15817": 0, "user15915": 0, "user28855": 0, "user28856": 0, "user28858": 0, "user28917": 0, "user29001": 0, "user29193": 0, "user29219": 0, "user29260": 0, "user29263": 0, "user29280": 0, "user29299": 0, "user29318": 0, "user29342": 0, "user28697": 0, "user28713": 0, "user29179": 0, "user29182": 0, "user29187": 0, "user29192": 0, "user29208": 0, "user29212": 0, "user29230": 0, "user29241": 0, "user29247": 0, "user29266": 1, "user29285": 0}, "types": {"user4550": "lootboxes", "user4554": "lootboxes", "user4808": "lootboxes", "user482": "lootboxes", "user485": "lootboxes", "user5158": "lootboxes", "user531": "lootboxes", "user546": "lootboxes", "user557": "lootboxes", "user6190": "lootboxes", "user6463": "lootboxes", "user6995": "lootboxes", "user7135": "lootboxes", "user7194": "lootboxes", "user997": "lootboxes", "user4174": "lootboxes", "user4203": "onlinegaming", "user4218": "lootboxes", "user4222": "lootboxes", "user4333": "lootboxes", "user4545": "lootboxes", "user4581": "lootboxes", "user4840": "lootboxes", "user5188": "lootboxes", "user5354": "betting", "user5913": "lootboxes", "user5975": "onlinegaming", "user6062": "lootboxes", "user6128": "lootboxes", "user6576": "onlinegaming", "user6927": "lootboxes", "user6937": "betting", "user7061": "lootboxes", "user7144": "lootboxes", "user7244": "lootboxes", "user18721": "lootboxes", "user18730": "lootboxes", "user18759": "lootboxes", "user18891": "lootboxes", "user18944": "lootboxes", "user19224": "lootboxes", "user19263": "lootboxes", "user19444": "lootboxes", "user20483": "lootboxes", "user20639": "lootboxes", "user21289": "lootboxes", "user21294": "onlinegaming", "user21422": "onlinegaming", "user22380": "lootboxes", "user23816": "lootboxes", "user24387": "lootboxes", "user24513": "onlinegaming", "user27647": "lootboxes", "user27670": "lootboxes", "user28298": "lootboxes", "user19643": "lootboxes", "user19737": "lootboxes", "user19767": "lootboxes", "user ...
# Submit to server is disabled. Data saved locally.
# Saved Task 2 - Run 0 to ./data/preds/task2/run0.json

# %%
print(client.all_messages_task1)
# Out:
# [{'id_message': 83834259853, 'nick': 'user4550', 'round': 1, 'message': 'Pues no sé', 'platform': 'Telegram', 'date': '2019-07-06 20:03:29+01:00'}, {'id_message': 40146258029, 'nick': 'user4554', 'round': 1, 'message': 'A más de 10 corners .', 'platform': 'Telegram', 'date': '2019-07-21 23:15:09+01:00'}, {'id_message': 64270929250, 'nick': 'user4808', 'round': 1, 'message': 'veis esto ?', 'platform': 'Telegram', 'date': '2020-07-11 15:33:24+01:00'}, {'id_message': 85647408793, 'nick': 'user482', 'round': 1, 'message': 'Venga coño , a ver si tiran jajajajaja', 'platform': 'Telegram', 'date': '2020-08-20 22:29:21+01:00'}, {'id_message': 84459180089, 'nick': 'user485', 'round': 1, 'message': 'Gracias', 'platform': 'Telegram', 'date': '2020-07-18 13:50:01+01:00'}, {'id_message': 24023936936, 'nick': 'user5158', 'round': 1, 'message': 'Si la paso ya seguro alguno dice es baja 😊 😊', 'platform': 'Telegram', 'date': '2020-12-24 14:12:58+01:00'}, {'id_message': 35088806108, 'nick': 'user531', 'round': 1, 'message': 'Perfecto', 'platform': 'Telegram', 'date': '2019-09-27 20:05:50+01:00'}, {'id_message': 93108233151, 'nick': 'user546', 'round': 1, 'message': '¿ Y dónde puedo ver mis códigos de cada web para ponerlos en el formulario ?', 'platform': 'Telegram', 'date': '2019-09-28 09:06:33+01:00'}, {'id_message': 43609978113, 'nick': 'user557', 'round': 1, 'message': 'Pierdes', 'platform': 'Telegram', 'date': '2021-08-19 14:11:58+01:00'}, {'id_message': 2377456107, 'nick': 'user6190', 'round': 1, 'message': 'O marca el elche y remonta el lugo o f', 'platform': 'Telegram', 'date': '2020-07-20 22:13:23+01:00'}, {'id_message': 58225338180, 'nick': 'user6463', 'round': 1, 'message': 'Ha fallado dos el puto lewan solo y muller tmb', 'platform': 'Telegram', 'date': '2020-08-19 22:39:38+01:00'}, {'id_message': 72741570022, 'nick': 'user6995', 'round': 1, 'message': 'Cuenta joven del Santander . Te regalan una cubertería', 'platform': 'Telegram', 'date': '2022-03-06 14:51:25+01:00'}, {'id_message': 28702610724, 'nick': 'user7135', 'round': 1, 'message': 'Xq pille cuotas buenas así de mdvev isner', 'platform': 'Telegram', 'date': '2022-05-24 22:24:57+01:00'}, {'id_message': 27049514643, 'nick': 'user7194', 'round': 1, 'message': 'Yo creo q es muy probable que francia gane y aparte saque almenos 1 corner mas q dinamarca en cada parte y tambien que chute 1 vez a porteria mas en cada parte', 'platform': 'Telegram', 'date': '2022-06-03 11:26:44+01:00'}, {'id_message': 56091675706, 'nick': 'user997', 'round': 1, 'message': 'Jajajajaja', 'platform': 'Telegram', 'date': '2022-08-08 07:58:05+01:00'}, {'id_message': 82482779557, 'nick': 'user4174', 'round': 1, 'message': 'Si deposito mediante visa despues me pueden devolver como me devuelven el dinero ?', 'platform': 'Telegram', 'date': '2019-05-25 08:23:07+01:00'}, {'id_message': 32268857485, 'nick': 'user4203', 'round': 1, 'message': 'Una duda , para registrar con luckia no aceptamos el bono no ?', 'platform': 'Telegram', 'date': '2019-05-25 15:08:38+01:00'}, {'id_message': 21245033410, 'nick': 'user4218', 'round': 1, 'message': 'Me puedo registrar solo en una ? Esque en Wh me pone un error y que contacte con atención al cliente', 'platform': 'Telegram', 'date': '2019-05-25 18:39:18+01:00'}, {'id_message': 57868836491, 'nick': 'user4222', 'round': 1, 'message': 'Buenas noches , simplemente quería asegurarme de que con registrarte en ambas páginas ahí indicadas y luego rellenar el pequeño formulario ya estaría todo correcto , no ?', 'platform': 'Telegram', 'date': '2019-05-25 22:35:18+01:00'}, {'id_message': 2028959453, 'nick': 'user4333', 'round': 1, 'message': 'Mi cabeza va con el Tottenham pero mi cartera con el Liverpool', 'platform': 'Telegram', 'date': '2019-06-01 14:18:47+01:00'}, {'id_message': 82386579166, 'nick': 'user4545', 'round': 1, 'message': '😫', 'platform': 'Telegram', 'date': '2019-06-21 11:56:42+01:00'}, {'id_message': 28343102930, 'nick': 'user4581', 'round': 1, 'message': 'Que gana Me ...

# %%
client.get_messages_task1(retries=5, backoff=0.1)
# Out:
# Task 1: Retrieved 160 messages
# [{'id_message': 83834259853,
#   'nick': 'user4550',
#   'round': 1,
#   'message': 'Pues no sé',
#   'platform': 'Telegram',
#   'date': '2019-07-06 20:03:29+01:00'},
#  {'id_message': 40146258029,
#   'nick': 'user4554',
#   'round': 1,
#   'message': 'A más de 10 corners .',
#   'platform': 'Telegram',
#   'date': '2019-07-21 23:15:09+01:00'},
#  {'id_message': 64270929250,
#   'nick': 'user4808',
#   'round': 1,
#   'message': 'veis esto ?',
#   'platform': 'Telegram',
#   'date': '2020-07-11 15:33:24+01:00'},
#  {'id_message': 85647408793,
#   'nick': 'user482',
#   'round': 1,
#   'message': 'Venga coño , a ver si tiran jajajajaja',
#   'platform': 'Telegram',
#   'date': '2020-08-20 22:29:21+01:00'},
#  {'id_message': 84459180089,
#   'nick': 'user485',
#   'round': 1,
#   'message': 'Gracias',
#   'platform': 'Telegram',
#   'date': '2020-07-18 13:50:01+01:00'},
#  {'id_message': 24023936936,
#   'nick': 'user5158',
#   'round': 1,
#   'message': 'Si la paso ya seguro alguno dice es baja 😊 😊',
#   'platform': 'Telegram',
#   'date': '2020-12-24 14:12:58+01:00'},
#  {'id_message': 35088806108,
#   'nick': 'user531',
#   'round': 1,
#   'message': 'Perfecto',
#   'platform': 'Telegram',
#   'date': '2019-09-27 20:05:50+01:00'},
#  {'id_message': 93108233151,
#   'nick': 'user546',
#   'round': 1,
#   'message': '¿ Y dónde puedo ver mis códigos de cada web para ponerlos en el formulario ?',
#   'platform': 'Telegram',
#   'date': '2019-09-28 09:06:33+01:00'},
#  {'id_message': 43609978113,
#   'nick': 'user557',
#   'round': 1,
#   'message': 'Pierdes',
#   'platform': 'Telegram',
#   'date': '2021-08-19 14:11:58+01:00'},
#  {'id_message': 2377456107,
#   'nick': 'user6190',
#   'round': 1,
#   'message': 'O marca el elche y remonta el lugo o f',
#   'platform': 'Telegram',
#   'date': '2020-07-20 22:13:23+01:00'},
#  {'id_message': 58225338180,
#   'nick': 'user6463',
#   'round': 1,
#   'message': 'Ha fallado dos el puto lewan solo y muller tmb',
#   'platform': 'Telegram',
#   'date': '2020-08-19 22:39:38+01:00'},
#  {'id_message': 72741570022,
#   'nick': 'user6995',
#   'round': 1,
#   'message': 'Cuenta joven del Santander . Te regalan una cubertería',
#   'platform': 'Telegram',
#   'date': '2022-03-06 14:51:25+01:00'},
#  {'id_message': 28702610724,
#   'nick': 'user7135',
#   'round': 1,
#   'message': 'Xq pille cuotas buenas así de mdvev isner',
#   'platform': 'Telegram',
#   'date': '2022-05-24 22:24:57+01:00'},
#  {'id_message': 27049514643,
#   'nick': 'user7194',
#   'round': 1,
#   'message': 'Yo creo q es muy probable que francia gane y aparte saque almenos 1 corner mas q dinamarca en cada parte y tambien que chute 1 vez a porteria mas en cada parte',
#   'platform': 'Telegram',
#   'date': '2022-06-03 11:26:44+01:00'},
#  {'id_message': 56091675706,
#   'nick': 'user997',
#   'round': 1,
#   'message': 'Jajajajaja',
#   'platform': 'Telegram',
#   'date': '2022-08-08 07:58:05+01:00'},
#  {'id_message': 82482779557,
#   'nick': 'user4174',
#   'round': 1,
#   'message': 'Si deposito mediante visa despues me pueden devolver como me devuelven el dinero ?',
#   'platform': 'Telegram',
#   'date': '2019-05-25 08:23:07+01:00'},
#  {'id_message': 32268857485,
#   'nick': 'user4203',
#   'round': 1,
#   'message': 'Una duda , para registrar con luckia no aceptamos el bono no ?',
#   'platform': 'Telegram',
#   'date': '2019-05-25 15:08:38+01:00'},
#  {'id_message': 21245033410,
#   'nick': 'user4218',
#   'round': 1,
#   'message': 'Me puedo registrar solo en una ? Esque en Wh me pone un error y que contacte con atención al cliente',
#   'platform': 'Telegram',
#   'date': '2019-05-25 18:39:18+01:00'},
#  {'id_message': 57868836491,
#   'nick': 'user4222',
#   'round': 1,
#   'message': 'Buenas noches , simplemente quería asegurarme de que con registrarte en ambas páginas ahí indicadas y luego rellenar el pequeño formulario ya estaría todo correcto , no ?',
#   'platform': 'Telegram',
#   'date': '2019-05-25 22:35:18+01:00'},
#  {'id_message': 2028959453,
#   'nick': 'user4333',
#   'round': 1,
#   'message': 'Mi cabeza va con el Tottenham pero mi cartera con el Liverpool',
#   'platform': 'Telegram',
#   'date': '2019-06-01 14:18:47+01:00'},
#  {'id_message': 82386579166,
#   'nick': 'user4545',
#   'round': 1,
#   'message': '😫',
#   'platform': 'Telegram',
#   'date': '2019-06-21 11:56:42+01:00'},
#  {'id_message': 28343102930,
#   'nick': 'user4581',
#   'round': 1,
#   'message': 'Que gana Medellín ?',
#   'platform': 'Telegram',
#   'date': '2019-07-15 01:38:44+01:00'},
#  {'id_message': 24776236467,
#   'nick': 'user4840',
#   'round': 1,
#   'message': 'pero entonces , pones 20 € en cada sitio , y qué haces ?',
#   'platform': 'Telegram',
#   'date': '2019-08-28 22:25:47+01:00'},
#  {'id_message': 48147765245,
#   'nick': 'user5188',
#   'round': 1,
#   'message': 'He visto más veces esto pero no tengo ni idea de cómo funciona , alguien podría decirme que hay que hacer ? ( A parte de meter los 20 € en cada casa )',
#   'platform': 'Telegram',
#   'date': '2019-10-29 18:08:40+01:00'},
#  {'id_message': 27627773796,
#   'nick': 'user5354',
#   'round': 1,
#   'message': 'Buenas tardes a todos ! Todo hecho , mañana saldran las apuestas entonces ?',
#   'platform': 'Telegram',
#   'date': '2019-10-30 11:24:04+01:00'},
#  {'id_message': 30844408277,
#   'nick': 'user5913',
#   'round': 1,
#   'message': 'Hecho . Voy ver mi nick para el formulario',
#   'platform': 'Telegram',
#   'date': '2020-02-21 21:56:51+01:00'},
#  {'id_message': 65534529286,
#   'nick': 'user5975',
#   'round': 1,
#   'message': 'Buenos días . He intentado registrarme en el enlace de WH pero me dice al finalizar que me ponga en contacto con atención al cliente . ¿ A alguien le ha pasado ?',
#   'platform': 'Telegram',
#   'date': '2020-02-26 10:06:01+01:00'},
#  {'id_message': 43539668750,
#   'nick': 'user6062',
#   'round': 1,
#   'message': 'sabeis si nos podemos registrar con DNI caducado ?',
#   'platform': 'Telegram',
#   'date': '2020-07-08 00:40:53+01:00'},
#  {'id_message': 41558258074,
#   'nick': 'user6128',
#   'round': 1,
#   'message': 'La promoción está restringida a jugadores españoles o residentes en España',
#   'platform': 'Telegram',
#   'date': '2020-07-08 14:25:10+01:00'},
#  {'id_message': 80165587680,
#   'nick': 'user6576',
#   'round': 1,
#   'message': 'Sigue sin funcionar mr green ?',
#   'platform': 'Telegram',
#   'date': '2020-09-24 13:28:07+01:00'},
#  {'id_message': 22344619925,
#   'nick': 'user6927',
#   'round': 1,
#   'message': 'Estaría bien hacer una combinada con la mayoría de los encuentros internacionales',
#   'platform': 'Telegram',
#   'date': '2020-11-11 07:53:51+01:00'},
#  {'id_message': 32517105716,
#   'nick': 'user6937',
#   'round': 1,
#   'message': 'Hola a todos soy Eva , este grupo es para comentar apuestas ?',
#   'platform': 'Telegram',
#   'date': '2020-11-16 11:09:01+01:00'},
#  {'id_message': 65458878118,
#   'nick': 'user7061',
#   'round': 1,
#   'message': 'Que tal la ven',
#   'platform': 'Telegram',
#   'date': '2021-05-09 20:41:25+01:00'},
#  {'id_message': 74739835630,
#   'nick': 'user7144',
#   'round': 1,
#   'message': 'Buenas ! !',
#   'platform': 'Telegram',
#   'date': '2022-02-05 20:48:07+01:00'},
#  {'id_message': 83369944157,
#   'nick': 'user7244',
#   'round': 1,
#   'message': 'Buenas tardes chicos',
#   'platform': 'Telegram',
#   'date': '2022-09-24 19:06:33+01:00'},
#  {'id_message': 75357050457,
#   'nick': 'user18721',
#   'round': 1,
#   'message': 'Aztec',
#   'platform': 'Twitch',
#   'date': '2023-02-16 01:15:35+01:00'},
#  {'id_message': 19227249914,
#   'nick': 'user18730',
#   'round': 1,
#   'message': '3 2 4 1 5',
#   'platform': 'Twitch',
#   'date': '2023-01-19 19:14:06+01:00'},
#  {'id_message': 82441829624,
#   'nick': 'user18759',
#   'round': 1,
#   'message': 'llamarle piru estaría bien tambien',
#   'platform': 'Twitch',
#   'date': '2023-01-15 20:44:12+01:00'},
#  {'id_message': 55395654874,
#   'nick': 'user18891',
#   'round': 1,
#   'message': 'jon siendo yo de andorra puedo retirar dinero del casino',
#   'platform': 'Twitch',
#   'date': '2023-01-19 20:44:11+01:00'},
#  {'id_message': 85550582714,
#   'nick': 'user18944',
#   'round': 1,
#   'message': '@USER y en zaragoza pero luego no quedas con ellos )',
#   'platform': 'Twitch',
#   'date': '2023-01-29 21:25:17+01:00'},
#  {'id_message': 11721684893,
#   'nick': 'user19224',
#   'round': 1,
#   'message': '?',
#   'platform': 'Twitch',
#   'date': '2023-02-19 20:14:48+01:00'},
#  {'id_message': 9660921477,
#   'nick': 'user19263',
#   'round': 1,
#   'message': 'la splash es la q paga parece',
#   'platform': 'Twitch',
#   'date': '2023-01-20 01:42:26+01:00'},
#  {'id_message': 90853794411,
#   'nick': 'user19444',
#   'round': 1,
#   'message': 'como ? ? ?',
#   'platform': 'Twitch',
#   'date': '2023-02-23 02:05:05+01:00'},
#  {'id_message': 84928767275,
#   'nick': 'user20483',
#   'round': 1,
#   'message': 'una madame',
#   'platform': 'Twitch',
#   'date': '2023-02-19 22:33:54+01:00'},
#  {'id_message': 38621083894,
#   'nick': 'user20639',
#   'round': 1,
#   'message': 'si tienen un problema te van a hablar diciendo que tienen un problema pero si tu tienes el problema se la pela',
#   'platform': 'Twitch',
#   'date': '2023-02-20 01:00:48+01:00'},
#  {'id_message': 1587832776,
#   'nick': 'user21289',
#   'round': 1,
#   'message': 'hahahaha',
#   'platform': 'Twitch',
#   'date': '2023-01-18 02:36:30+01:00'},
#  {'id_message': 39031423188,
#   'nick': 'user21294',
#   'round': 1,
#   'message': 'Book of cats joper',
#   'platform': 'Twitch',
#   'date': '2023-02-22 22:35:11+01:00'},
#  {'id_message': 52607408541,
#   'nick': 'user21422',
#   'round': 1,
#   'message': 'micro stream de 3 años se viene BloodTrail',
#   'platform': 'Twitch',
#   'date': '2023-03-02 01:03:02+01:00'},
#  {'id_message': 25591620138,
#   'nick': 'user22380',
#   'round': 1,
#   'message': 'Hay mucho eco BloodTrail',
#   'platform': 'Twitch',
#   'date': '2023-03-06 22:36:00+01:00'},
#  {'id_message': 34537230759,
#   'nick': 'user23816',
#   'round': 1,
#   'message': 'jajajajajajajajajaj',
#   'platform': 'Twitch',
#   'date': '2023-02-22 22:51:15+01:00'},
#  {'id_message': 68999036030,
#   'nick': 'user24387',
#   'round': 1,
#   'message': 'peepoSalute 🛠 ️ 🟥',
#   'platform': 'Twitch',
#   'date': '2023-03-06 23:18:29+01:00'},
#  {'id_message': 59228804157,
#   'nick': 'user24513',
#   'round': 1,
#   'message': 'Tiradas a 200 en Esqueleto Explosivo 2 Prayge Tiradas a 200 en Esqueleto Explosivo 2 Prayge Tiradas a 200 en Esqueleto Explosivo 2 Prayge Tiradas a 200 en Esqueleto Explosivo 2 Prayge Tiradas a 200 en Esqueleto Explosivo 2 Prayge Tiradas a 200 en Esqueleto Explosivo 2 Prayge',
#   'platform': 'Twitch',
#   'date': '2023-02-22 23:03:06+01:00'},
#  {'id_message': 25453295903,
#   'nick': 'user27647',
#   'round': 1,
#   'message': 'Y nacho también',
#   'platform': 'Twitch',
#   'date': '2022-11-02 16:08:33+01:00'},
#  {'id_message': 98868467794,
#   'nick': 'user27670',
#   'round': 1,
#   'message': 'Ruleeeeee',
#   'platform': 'Twitch',
#   'date': '2022-11-02 20:29:15+01:00'},
#  {'id_message': 49451377663,
#   'nick': 'user28298',
#   'round': 1,
#   'message': 'pobre croupier esta pal orto',
#   'platform': 'Twitch',
#   'date': '2023-03-08 02:46:14+01:00'},
#  {'id_message': 13996087964,
#   'nick': 'user19643',
#   'round': 1,
#   'message': 'scoter',
#   'platform': 'Twitch',
#   'date': '2023-01-12 23:01:06+01:00'},
#  {'id_message': 79237563989,
#   'nick': 'user19737',
#   'round': 1,
#   'message': 'apaga la putísima santa radio',
#   'platform': 'Twitch',
#   'date': '2023-01-12 23:26:12+01:00'},
#  {'id_message': 6852061656,
#   'nick': 'user19767',
#   'round': 1,
#   'message': 'agítalooooo',
#   'platform': 'Twitch',
#   'date': '2023-01-12 23:34:25+01:00'},
#  {'id_message': 9897704829,
#   'nick': 'user19891',
#   'round': 1,
#   'message': 'miaau que es gata xD',
#   'platform': 'Twitch',
#   'date': '2023-01-13 00:18:17+01:00'},
#  {'id_message': 81722625736,
#   'nick': 'user19956',
#   'round': 1,
#   'message': 'bizarrap',
#   'platform': 'Twitch',
#   'date': '2023-01-13 00:31:35+01:00'},
#  {'id_message': 47743313929,
#   'nick': 'user19982',
#   'round': 1,
#   'message': 'shakiraWakaWaka shakiraWakaWaka shakiraWakaWaka shakiraWakaWaka',
#   'platform': 'Twitch',
#   'date': '2023-01-13 00:38:37+01:00'},
#  {'id_message': 82508370715,
#   'nick': 'user20079',
#   'round': 1,
#   'message': 'zombie',
#   'platform': 'Twitch',
#   'date': '2023-01-13 01:06:58+01:00'},
#  {'id_message': 49130131204,
#   'nick': 'user20546',
#   'round': 1,
#   'message': 'bien mi hermano tu q como vas',
#   'platform': 'Twitch',
#   'date': '2023-01-15 20:21:36+01:00'},
#  {'id_message': 66076811372,
#   'nick': 'user20785',
#   'round': 1,
#   'message': 'que es eso del wager',
#   'platform': 'Twitch',
#   'date': '2023-01-29 13:48:36+01:00'},
#  {'id_message': 93493885762,
#   'nick': 'user21081',
#   'round': 1,
#   'message': 'Busca big top bonanza megaways',
#   'platform': 'Twitch',
#   'date': '2023-01-30 00:34:46+01:00'},
#  {'id_message': 32130638060,
#   'nick': 'user21103',
#   'round': 1,
#   'message': 'aaaaaamigoo',
#   'platform': 'Twitch',
#   'date': '2023-01-30 01:17:51+01:00'},
#  {'id_message': 67779140309,
#   'nick': 'user21282',
#   'round': 1,
#   'message': "' Cause this is triller , thriller girl !",
#   'platform': 'Twitch',
#   'date': '2023-02-08 22:46:24+01:00'},
#  {'id_message': 20200954527,
#   'nick': 'user21406',
#   'round': 1,
#   'message': 'lmao',
#   'platform': 'Twitch',
#   'date': '2023-02-09 00:00:19+01:00'},
#  {'id_message': 7840052784,
#   'nick': 'user21595',
#   'round': 1,
#   'message': '¡ Oi',
#   'platform': 'Twitch',
#   'date': '2023-02-09 01:54:23+01:00'},
#  {'id_message': 52784299018,
#   'nick': 'user22309',
#   'round': 1,
#   'message': 'break Bones que como la fruit duel pero tira una mano que tira respins subiendo el multi',
#   'platform': 'Twitch',
#   'date': '2023-02-14 22:55:34+01:00'},
#  {'id_message': 28615653137,
#   'nick': 'user22341',
#   'round': 1,
#   'message': 'una Cube 2 ? ? ? puede ser o no',
#   'platform': 'Twitch',
#   'date': '2023-02-14 23:17:06+01:00'},
#  {'id_message': 94082367979,
#   'nick': 'user22443',
#   'round': 1,
#   'message': 'ouuuu',
#   'platform': 'Twitch',
#   'date': '2023-02-15 00:03:00+01:00'},
#  {'id_message': 21765871547,
#   'nick': 'user24038',
#   'round': 1,
#   'message': '! ou',
#   'platform': 'Twitch',
#   'date': '2023-02-28 23:44:15+01:00'},
#  {'id_message': 61966057083,
#   'nick': 'user26003',
#   'round': 1,
#   'message': 'sólo 4 puntos @USER raton',
#   'platform': 'Twitch',
#   'date': '2023-03-02 00:02:32+01:00'},
#  {'id_message': 66103459372,
#   'nick': 'user26424',
#   'round': 1,
#   'message': 'Es revivir en peak power',
#   'platform': 'Twitch',
#   'date': '2023-03-03 05:33:19+01:00'},
#  {'id_message': 60938454959,
#   'nick': 'user26426',
#   'round': 1,
#   'message': 'bocaaaaaaa',
#   'platform': 'Twitch',
#   'date': '2023-03-03 05:36:07+01:00'},
#  {'id_message': 34470187267,
#   'nick': 'user28183',
#   'round': 1,
#   'message': 'hermano me meto a twitter y tan funando a coscu que chucha',
#   'platform': 'Twitch',
#   'date': '2023-03-07 23:41:30+01:00'},
#  {'id_message': 72746102524,
#   'nick': 'user28187',
#   'round': 1,
#   'message': 'el año de las funas',
#   'platform': 'Twitch',
#   'date': '2023-03-07 23:41:35+01:00'},
#  {'id_message': 1213867065,
#   'nick': 'user28306',
#   'round': 1,
#   'message': 'peliemo',
#   'platform': 'Twitch',
#   'date': '2023-03-08 00:54:31+01:00'},
#  {'id_message': 18541474520,
#   'nick': 'user7555',
#   'round': 1,
#   'message': 'IOTA AGUANTANDO COMO VARON ESE SOPORTE',
#   'platform': 'Telegram',
#   'date': '2021-04-22 20:15:29+01:00'},
#  {'id_message': 87185652761,
#   'nick': 'user7579',
#   'round': 1,
#   'message': ': 0',
#   'platform': 'Telegram',
#   'date': '2022-11-07 01:30:09+01:00'},
#  {'id_message': 90505675782,
#   'nick': 'user7580',
#   'round': 1,
#   'message': 'tiren una moneda si les parece que esta para scalping porque yo intente y me pego en 20 menos',
#   'platform': 'Telegram',
#   'date': '2021-05-20 17:32:11+01:00'},
#  {'id_message': 1141281038,
#   'nick': 'user7591',
#   'round': 1,
#   'message': 'de no pasa 39.800',
#   'platform': 'Telegram',
#   'date': '2022-03-15 23:14:35+01:00'},
#  {'id_message': 41285125053,
#   'nick': 'user7592',
#   'round': 1,
#   'message': 'Ufff lo que se viene para BTC , la vela mensual también es clarísima nos vamos al infierno',
#   'platform': 'Telegram',
#   'date': '2021-05-30 01:51:33+01:00'},
#  {'id_message': 77538089341,
#   'nick': 'user7613',
#   'round': 1,
#   'message': 'Pasa el pdf si puedes',
#   'platform': 'Telegram',
#   'date': '2021-05-09 21:51:10+01:00'},
#  {'id_message': 63371685585,
#   'nick': 'user7621',
#   'round': 1,
#   'message': 'No',
#   'platform': 'Telegram',
#   'date': '2021-05-08 03:16:16+01:00'},
#  {'id_message': 19230634644,
#   'nick': 'user7652',
#   'round': 1,
#   'message': 'tal cual smart money',
#   'platform': 'Telegram',
#   'date': '2022-05-29 06:42:42+01:00'},
#  {'id_message': 60712089986,
#   'nick': 'user7660',
#   'round': 1,
#   'message': 'tambien tengo mi resistencia por ahi . . viene de una caida muy pronunciada , y van 11 velitas en un micro canal al alza desde los 36.5 k ... que podrian ser el banderin ... y puse MICRO canal , , , no que esta en alza',
#   'platform': 'Telegram',
#   'date': '2021-06-04 19:07:40+01:00'},
#  {'id_message': 16042372049,
#   'nick': 'user7679',
#   'round': 1,
#   'message': 'Yo entre en short',
#   'platform': 'Telegram',
#   'date': '2022-06-05 00:09:23+01:00'},
#  {'id_message': 38517890939,
#   'nick': 'user7698',
#   'round': 1,
#   'message': 'Se ve bien , pero mejor ahí abajo',
#   'platform': 'Telegram',
#   'date': '2021-04-17 01:33:23+01:00'},
#  {'id_message': 17294782749,
#   'nick': 'user7816',
#   'round': 1,
#   'message': 'Si rompe los 11.340 volvé a entrar en long',
#   'platform': 'Telegram',
#   'date': '2022-07-30 00:03:55+01:00'},
#  {'id_message': 46880871190,
#   'nick': 'user7836',
#   'round': 1,
#   'message': 'Les iba a pasar el enlace para que vean la conferencia de Jerome Powell en vivo . Pero no me lo permite',
#   'platform': 'Telegram',
#   'date': '2022-01-26 15:06:33+01:00'},
#  {'id_message': 78168063787,
#   'nick': 'user7876',
#   'round': 1,
#   'message': 'Cómo preguntaste pensé que ibas a operar',
#   'platform': 'Telegram',
#   'date': '2022-02-02 19:11:18+01:00'},
#  {'id_message': 83517584190,
#   'nick': 'user7884',
#   'round': 1,
#   'message': 'Juro que si eso pasa aprendi mi leccion nunca mas sin stop loss ... Vamos btc .. esta te pido no mas .. 😂',
#   'platform': 'Telegram',
#   'date': '2022-07-01 00:33:17+01:00'},
#  {'id_message': 81330894567,
#   'nick': 'user7899',
#   'round': 1,
#   'message': 'De cual ?',
#   'platform': 'Telegram',
#   'date': '2021-11-30 04:25:04+01:00'},
#  {'id_message': 68784403963,
#   'nick': 'user7920',
#   'round': 1,
#   'message': 'Creen que baje btc ?',
#   'platform': 'Telegram',
#   'date': '2021-07-21 18:49:02+01:00'},
#  {'id_message': 83738586853,
#   'nick': 'user8023',
#   'round': 1,
#   'message': 'He mandando muchísimas señales a este grupo 😅 solo que estoy de viaje con poco internet y de rato en rato hago scalping jaja',
#   'platform': 'Telegram',
#   'date': '2021-04-16 02:46:45+01:00'},
#  {'id_message': 15582817417,
#   'nick': 'user8137',
#   'round': 1,
#   'message': 'JAJAJAJAJAJAJ',
#   'platform': 'Telegram',
#   'date': '2021-05-05 16:37:57+01:00'},
#  {'id_message': 32205090302,
#   'nick': 'user8303',
#   'round': 1,
#   'message': 'hombre , yo voy en corto , ya ves ,',
#   'platform': 'Telegram',
#   'date': '2022-09-12 16:12:29+01:00'},
#  {'id_message': 3225132671,
#   'nick': 'user8404',
#   'round': 1,
#   'message': 'a que se debe tanta subia en matic ?',
#   'platform': 'Telegram',
#   'date': '2021-05-19 08:28:32+01:00'},
#  {'id_message': 12429323221,
#   'nick': 'user8497',
#   'round': 1,
#   'message': 'La paciencia paga 🙈 🙈',
#   'platform': 'Telegram',
#   'date': '2022-04-11 19:08:11+01:00'},
#  {'id_message': 98389518690,
#   'nick': 'user8696',
#   'round': 1,
#   'message': 'rompemos rango y a 45k , si rompemos 45k a 47',
#   'platform': 'Telegram',
#   'date': '2022-02-15 16:53:49+01:00'},
#  {'id_message': 98895976316,
#   'nick': 'user8775',
#   'round': 1,
#   'message': 'Está buenísima a largo plazo',
#   'platform': 'Telegram',
#   'date': '2022-07-04 06:30:37+01:00'},
#  {'id_message': 24125884588,
#   'nick': 'user8834',
#   'round': 1,
#   'message': '/ c FTM',
#   'platform': 'Telegram',
#   'date': '2022-03-10 19:00:32+01:00'},
#  {'id_message': 49300612589,
#   'nick': 'user8875',
#   'round': 1,
#   'message': 'btc baja a 33 k y rebota hasta los 37k',
#   'platform': 'Telegram',
#   'date': '2021-07-01 07:24:55+01:00'},
#  {'id_message': 30989642348,
#   'nick': 'user8924',
#   'round': 1,
#   'message': 'Long a todo',
#   'platform': 'Telegram',
#   'date': '2022-06-07 04:46:37+01:00'},
#  {'id_message': 20012431418,
#   'nick': 'user8945',
#   'round': 1,
#   'message': 'Yo la veo yendose a 7,4 a buscar liquidez',
#   'platform': 'Telegram',
#   'date': '2022-06-04 19:09:24+01:00'},
#  {'id_message': 7222036136,
#   'nick': 'user8971',
#   'round': 1,
#   'message': 'Dos veces hay que hacer demo ?',
#   'platform': 'Telegram',
#   'date': '2023-01-01 16:25:30+01:00'},
#  {'id_message': 25751079061,
#   'nick': 'user9116',
#   'round': 1,
#   'message': 'Alguna entrada ?',
#   'platform': 'Telegram',
#   'date': '2021-08-16 15:54:01+01:00'},
#  {'id_message': 50555788910,
#   'nick': 'user9131',
#   'round': 1,
#   'message': 'Millonario en pesos es cualquira hoy , en dolares somos algunos pocos weew awantaa',
#   'platform': 'Telegram',
#   'date': '2021-05-30 22:37:32+01:00'},
#  {'id_message': 53380775630,
#   'nick': 'user9268',
#   'round': 1,
#   'message': 'jesus cry manaa',
#   'platform': 'Telegram',
#   'date': '2021-10-31 00:08:41+01:00'},
#  {'id_message': 34747538659,
#   'nick': 'user9358',
#   'round': 1,
#   'message': 'Cuando se enlista en rh',
#   'platform': 'Telegram',
#   'date': '2021-10-27 07:36:10+01:00'},
#  {'id_message': 56656881262,
#   'nick': 'user9366',
#   'round': 1,
#   'message': 'Entro un boot al parecer , es español',
#   'platform': 'Telegram',
#   'date': '2021-09-08 15:28:20+01:00'},
#  {'id_message': 77835879000,
#   'nick': 'user9457',
#   'round': 1,
#   'message': 'quieres combustible para tu shor ? jajajaja',
#   'platform': 'Telegram',
#   'date': '2023-01-19 00:45:15+01:00'},
#  {'id_message': 47713228031,
#   'nick': 'user13834',
#   'round': 1,
#   'message': 'Ya cerraste o le sigues aguantando ?',
#   'platform': 'Telegram',
#   'date': '2022-01-11 05:06:28+01:00'},
#  {'id_message': 86774312614,
#   'nick': 'user14047',
#   'round': 1,
#   'message': 'Estas seguro que va a subir ?',
#   'platform': 'Telegram',
#   'date': '2022-02-10 20:53:46+01:00'},
#  {'id_message': 28898642739,
#   'nick': 'user14065',
#   'round': 1,
#   'message': 'Buenas noches una consulta , que exchanges recomiendan , en cuanto a futuros con las comisiones más bajas',
#   'platform': 'Telegram',
#   'date': '2022-02-13 01:18:58+01:00'},
#  {'id_message': 17773012590,
#   'nick': 'user14232',
#   'round': 1,
#   'message': 'Hola amigos soy nuevo en esto , quiero entrar al mercado por miedo a que siga subiendo , pero tambien tengo miedo de entrar y que baje el precio , que me recomiendan hacer ? ? ?',
#   'platform': 'Telegram',
#   'date': '2022-03-01 16:16:53+01:00'},
#  {'id_message': 53726626126,
#   'nick': 'user14366',
#   'round': 1,
#   'message': 'sale long en rose',
#   'platform': 'Telegram',
#   'date': '2022-03-13 03:21:35+01:00'},
#  {'id_message': 27759897859,
#   'nick': 'user14382',
#   'round': 1,
#   'message': 'se pago el desayuno',
#   'platform': 'Telegram',
#   'date': '2022-03-15 04:39:04+01:00'},
#  {'id_message': 14007417522,
#   'nick': 'user14527',
#   'round': 1,
#   'message': 'Hola a todos',
#   'platform': 'Telegram',
#   'date': '2022-03-28 05:18:15+01:00'},
#  {'id_message': 51340522032,
#   'nick': 'user14529',
#   'round': 1,
#   'message': 'Waves ? ? 😅',
#   'platform': 'Telegram',
#   'date': '2022-03-29 01:42:17+01:00'},
#  {'id_message': 39386688833,
#   'nick': 'user14758',
#   'round': 1,
#   'message': 'Hasta cuánto crees que caiga ?',
#   'platform': 'Telegram',
#   'date': '2022-04-21 22:42:29+01:00'},
#  {'id_message': 99091017211,
#   'nick': 'user14793',
#   'round': 1,
#   'message': 'En unos meses vamos a ver a btc en 20k si en esta semana no rompe los 43k',
#   'platform': 'Telegram',
#   'date': '2022-04-26 17:53:24+01:00'},
#  {'id_message': 86658069947,
#   'nick': 'user14816',
#   'round': 1,
#   'message': 'Jaja verdad después lo mandó a 42 y se fue a 38',
#   'platform': 'Telegram',
#   'date': '2022-04-28 20:20:29+01:00'},
#  {'id_message': 88781174559,
#   'nick': 'user14920',
#   'round': 1,
#   'message': 'Que opinan del btc será que se esta recuerdo o estará esperando un bajonazo años 27000',
#   'platform': 'Telegram',
#   'date': '2022-05-11 17:00:17+01:00'},
#  {'id_message': 94856871402,
#   'nick': 'user15125',
#   'round': 1,
#   'message': 'Que onda con litelcoin ? Callo fuerte creen que se recupere a largo plazo ?',
#   'platform': 'Telegram',
#   'date': '2022-06-12 17:30:27+01:00'},
#  {'id_message': 79247542109,
#   'nick': 'user15166',
#   'round': 1,
#   'message': 'dale gafas',
#   'platform': 'Telegram',
#   'date': '2022-06-17 05:24:51+01:00'},
#  {'id_message': 4459135417,
#   'nick': 'user15212',
#   'round': 1,
#   'message': 'Quien me puede decir el comercio de binance horita , osea que por un dólar cuanto peso me user 15930',
#   'platform': 'Telegram',
#   'date': '2022-06-25 00:16:32+01:00'},
#  {'id_message': 64117608304,
#   'nick': 'user15400',
#   'round': 1,
#   'message': 'Hasta donde creen que llegará ?',
#   'platform': 'Telegram',
#   'date': '2022-07-26 20:59:59+01:00'},
#  {'id_message': 69645071262,
#   'nick': 'user15503',
#   'round': 1,
#   'message': 'vrg',
#   'platform': 'Telegram',
#   'date': '2022-08-09 15:57:01+01:00'},
#  {'id_message': 71774008021,
#   'nick': 'user15528',
#   'round': 1,
#   'message': 'yo entre en 1.0100 pesando que de hay bajaba y subio un poco mas',
#   'platform': 'Telegram',
#   'date': '2022-08-13 13:18:46+01:00'},
#  {'id_message': 70290093821,
#   'nick': 'user15817',
#   'round': 1,
#   'message': 'No veo sus aportes',
#   'platform': 'Telegram',
#   'date': '2022-10-26 15:12:47+01:00'},
#  {'id_message': 11987317369,
#   'nick': 'user15915',
#   'round': 1,
#   'message': 'Saludos',
#   'platform': 'Telegram',
#   'date': '2022-12-08 10:31:49+01:00'},
#  {'id_message': 30872863935,
#   'nick': 'user28855',
#   'round': 1,
#   'message': 'x50',
#   'platform': 'Twitch',
#   'date': '2020-08-13 08:23:10+01:00'},
#  {'id_message': 78399010598,
#   'nick': 'user28856',
#   'round': 1,
#   'message': 'x10000',
#   'platform': 'Twitch',
#   'date': '2020-08-13 08:23:10+01:00'},
#  {'id_message': 1159494626,
#   'nick': 'user28858',
#   'round': 1,
#   'message': 'llave 7 caja 7 capi',
#   'platform': 'Twitch',
#   'date': '2020-08-13 08:23:11+01:00'},
#  {'id_message': 63982514026,
#   'nick': 'user28917',
#   'round': 1,
#   'message': 'green go b',
#   'platform': 'Twitch',
#   'date': '2020-08-13 08:23:20+01:00'},
#  {'id_message': 94385595598,
#   'nick': 'user29001',
#   'round': 1,
#   'message': 'mira detrás de la teec',
#   'platform': 'Twitch',
#   'date': '2020-08-13 08:23:40+01:00'},
#  {'id_message': 97999473061,
#   'nick': 'user29193',
#   'round': 1,
#   'message': 'justamente sera lo que quiere la basura',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:38:33+01:00'},
#  {'id_message': 32096327422,
#   'nick': 'user29219',
#   'round': 1,
#   'message': 'increible como steam se lava las manos',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:41:26+01:00'},
#  {'id_message': 81845248794,
#   'nick': 'user29260',
#   'round': 1,
#   'message': 'la vulcan subio 15 usd en 2 dias @USER',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:50:58+01:00'},
#  {'id_message': 91964510116,
#   'nick': 'user29263',
#   'round': 1,
#   'message': 'unknown tenes alguna skin que la estés holdeando para ver si sube de precio ? skin o sticker',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:51:42+01:00'},
#  {'id_message': 85164137746,
#   'nick': 'user29280',
#   'round': 1,
#   'message': 'parece 2008 ese discord',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:59:00+01:00'},
#  {'id_message': 17472045170,
#   'nick': 'user29299',
#   'round': 1,
#   'message': 'dice que si dmarket te paga por la promocion o la recomiendas por que es realamente buena',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:06:08+01:00'},
#  {'id_message': 15043172420,
#   'nick': 'user29318',
#   'round': 1,
#   'message': 'unknown ni vos ves tus propios videos',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:12:00+01:00'},
#  {'id_message': 17852822859,
#   'nick': 'user29342',
#   'round': 1,
#   'message': '5k',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:15:01+01:00'},
#  {'id_message': 21452868561,
#   'nick': 'user28697',
#   'round': 1,
#   'message': 'Echamos un Clash entonces o un agario ?',
#   'platform': 'Twitch',
#   'date': '2022-02-26 18:22:09+01:00'},
#  {'id_message': 83771122219,
#   'nick': 'user28713',
#   'round': 1,
#   'message': 'jajajjajaa',
#   'platform': 'Twitch',
#   'date': '2022-02-26 18:22:09+01:00'},
#  {'id_message': 68608669504,
#   'nick': 'user29179',
#   'round': 1,
#   'message': 'el ka-ri anda a comprar 15 cajas mas jaja',
#   'platform': 'Twitch',
#   'date': '2023-03-19 20:22:17+01:00'},
#  {'id_message': 55516537134,
#   'nick': 'user29182',
#   'round': 1,
#   'message': 'son 3 los que hay el pudel el firely vc y el tog II',
#   'platform': 'Twitch',
#   'date': '2023-03-19 20:09:19+01:00'},
#  {'id_message': 69551764308,
#   'nick': 'user29187',
#   'round': 1,
#   'message': 'cs lo silencio para que no diga nada del source 2',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:12:40+01:00'},
#  {'id_message': 65497243901,
#   'nick': 'user29192',
#   'round': 1,
#   'message': 'yo el año que hice tuve calculo 1 y 2 , algebra y discreta',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:22:34+01:00'},
#  {'id_message': 35116543825,
#   'nick': 'user29208',
#   'round': 1,
#   'message': '(',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:15:35+01:00'},
#  {'id_message': 78851050558,
#   'nick': 'user29212',
#   'round': 1,
#   'message': 'yo lo note con el mouz holo',
#   'platform': 'Twitch',
#   'date': '2023-03-19 23:51:00+01:00'},
#  {'id_message': 76943504455,
#   'nick': 'user29230',
#   'round': 1,
#   'message': 'fff',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:20:17+01:00'},
#  {'id_message': 79181848024,
#   'nick': 'user29241',
#   'round': 1,
#   'message': 'F',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:25:41+01:00'},
#  {'id_message': 44434477140,
#   'nick': 'user29247',
#   'round': 1,
#   'message': '@USER x2',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:14:33+01:00'},
#  {'id_message': 69316191490,
#   'nick': 'user29266',
#   'round': 1,
#   'message': 'al principio nos echabas porque te daba verguenza',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:16:59+01:00'},
#  {'id_message': 67613128269,
#   'nick': 'user29285',
#   'round': 1,
#   'message': 'lo vi en un tiktok de loquendo',
#   'platform': 'Twitch',
#   'date': '2023-03-20 00:11:34+01:00'}]
